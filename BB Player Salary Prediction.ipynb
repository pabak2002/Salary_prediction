# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'nba2k-full.csv')
df.head()
# Out:
#                full_name  rating jersey                  team position  \
# 0           LeBron James      97    #23    Los Angeles Lakers        F
# 1          Kawhi Leonard      97     #2  Los Angeles Clippers        F
# 2  Giannis Antetokounmpo      96    #34       Milwaukee Bucks      F-G
# 3           Kevin Durant      96     #7         Brooklyn Nets        F
# 4           James Harden      96    #13       Houston Rockets        G
#
#       b_day       height                weight     salary country  draft_year  \
# 0  12/30/84   6-9 / 2.06  250 lbs. / 113.4 kg.  $37436858     USA        2003
# 1  06/29/91   6-7 / 2.01  225 lbs. / 102.1 kg.  $32742000     USA        2011
# 2  12/06/94  6-11 / 2.11  242 lbs. / 109.8 kg.  $25842697  Greece        2013
# 3  09/29/88  6-10 / 2.08  230 lbs. / 104.3 kg.  $37199000     USA        2007
# 4  08/26/89   6-5 / 1.96   220 lbs. / 99.8 kg.  $38199000     USA        2009
#
#   draft_round draft_peak          college  version
# ...

# %%
df.shape
# Out:
# (464, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 464 entries, 0 to 463
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   full_name    464 non-null    object
#  1   rating       464 non-null    int64
#  2   jersey       464 non-null    object
#  3   team         441 non-null    object
#  4   position     464 non-null    object
#  5   b_day        464 non-null    object
#  6   height       464 non-null    object
#  7   weight       464 non-null    object
#  8   salary       464 non-null    object
#  9   country      464 non-null    object
#  10  draft_year   464 non-null    int64
#  11  draft_round  464 non-null    object
#  12  draft_peak   464 non-null    object
#  13  college      388 non-null    object
#  14  version      464 non-null    object
# dtypes: int64(2), object(13)
# memory usage: 54.5+ KB

# %%
df.isnull()
# Out:
#      full_name  rating  jersey   team  position  b_day  height  weight  \
# 0        False   False   False  False     False  False   False   False
# 1        False   False   False  False     False  False   False   False
# 2        False   False   False  False     False  False   False   False
# 3        False   False   False  False     False  False   False   False
# 4        False   False   False  False     False  False   False   False
# ..         ...     ...     ...    ...       ...    ...     ...     ...
# 459      False   False   False  False     False  False   False   False
# 460      False   False   False  False     False  False   False   False
# 461      False   False   False  False     False  False   False   False
# 462      False   False   False  False     False  False   False   False
# 463      False   False   False  False     False  False   False   False
#
#      salary  country  draft_year  draft_round  draft_peak  college  version
# ...

# %%
df.isnull().sum()
# Out:
# full_name       0
# rating          0
# jersey          0
# team           23
# position        0
# b_day           0
# height          0
# weight          0
# salary          0
# country         0
# draft_year      0
# draft_round     0
# draft_peak      0
# college        76
# version         0
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# full_name      0
# rating         0
# jersey         0
# team           0
# position       0
# b_day          0
# height         0
# weight         0
# salary         0
# country        0
# draft_year     0
# draft_round    0
# draft_peak     0
# college        0
# version        0
# dtype: int64

# %%
df.drop(['full_name','b_day','height','weight','college'],axis=1,inplace=True)
df.head()
# Out:
#    rating jersey                   team position     salary country  \
# 1      97     #2   Los Angeles Clippers        F  $32742000     USA
# 3      96     #7          Brooklyn Nets        F  $37199000     USA
# 4      96    #13        Houston Rockets        G  $38199000     USA
# 5      95    #30  Golden State Warriors        G  $40231758     USA
# 6      94     #3     Los Angeles Lakers      F-C  $27093019     USA
#
#    draft_year draft_round draft_peak  version
# 1        2011           1         15  NBA2k20
# 3        2007           1          2  NBA2k20
# 4        2009           1          3  NBA2k20
# 5        2009           1          7  NBA2k20
# 6        2012           1          1  NBA2k20

# %%
df.isnull().sum()
# Out:
# rating         0
# jersey         0
# team           0
# position       0
# salary         0
# country        0
# draft_year     0
# draft_round    0
# draft_peak     0
# version        0
# dtype: int64

# %%
def rem_hash(val):
    val=val[1:]
    return int(val)
df['jersey']=df['jersey'].apply(rem_hash)

# %%
df.head()
# Out:
#    rating  jersey                   team position     salary country  \
# 1      97       2   Los Angeles Clippers        F  $32742000     USA
# 3      96       7          Brooklyn Nets        F  $37199000     USA
# 4      96      13        Houston Rockets        G  $38199000     USA
# 5      95      30  Golden State Warriors        G  $40231758     USA
# 6      94       3     Los Angeles Lakers      F-C  $27093019     USA
#
#    draft_year draft_round draft_peak  version
# 1        2011           1         15  NBA2k20
# 3        2007           1          2  NBA2k20
# 4        2009           1          3  NBA2k20
# 5        2009           1          7  NBA2k20
# 6        2012           1          1  NBA2k20

# %%
df['salary']=df['salary'].apply(rem_hash)
df.head()
# Out:
#    rating  jersey                   team position    salary country  \
# 1      97       2   Los Angeles Clippers        F  32742000     USA
# 3      96       7          Brooklyn Nets        F  37199000     USA
# 4      96      13        Houston Rockets        G  38199000     USA
# 5      95      30  Golden State Warriors        G  40231758     USA
# 6      94       3     Los Angeles Lakers      F-C  27093019     USA
#
#    draft_year draft_round draft_peak  version
# 1        2011           1         15  NBA2k20
# 3        2007           1          2  NBA2k20
# 4        2009           1          3  NBA2k20
# 5        2009           1          7  NBA2k20
# 6        2012           1          1  NBA2k20

# %%
df['position'].value_counts()
# Out:
# G      166
# F      123
# C       31
# F-C     26
# G-F     11
# F-G      7
# C-F      5
# Name: position, dtype: int64

# %%
df['team'].value_counts()
# Out:
# Brooklyn Nets             17
# Los Angeles Clippers      15
# Los Angeles Lakers        15
# Indiana Pacers            14
# Milwaukee Bucks           14
# Philadelphia 76ers        14
# Orlando Magic             14
# New Orleans Pelicans      14
# New York Knicks           13
# Chicago Bulls             13
# Toronto Raptors           13
# Minnesota Timberwolves    13
# Houston Rockets           13
# Memphis Grizzlies         12
# Detroit Pistons           12
# Sacramento Kings          12
# Phoenix Suns              12
# Miami Heat                12
# San Antonio Spurs         12
# Atlanta Hawks             12
# Denver Nuggets            12
# Golden State Warriors     11
# Dallas Mavericks          11
# Boston Celtics            11
# Portland Trail Blazers    11
# Washington Wizards        11
# Oklahoma City Thunder     10
# Cleveland Cavaliers       10
# Utah Jazz                  9
# Charlotte Hornets          7
# Name: team, dtype: int64

# %%
df['country'].value_counts()
# Out:
# USA                   315
# Canada                 15
# Australia               8
# Cameroon                5
# Nigeria                 3
# The Bahamas             2
# Ukraine                 2
# Mali                    1
# Egypt                   1
# Haiti                   1
# Angola                  1
# Germany                 1
# Italy                   1
# United Kingdom          1
# Japan                   1
# Israel                  1
# Austria                 1
# Senegal                 1
# Puerto Rico             1
# Philippines             1
# Lithuania               1
# New Zealand             1
# Finland                 1
# Dominican Republic      1
# Montenegro              1
# Greece                  1
# Name: country, dtype: int64

# %%
def rem_country(value):
    if(value not in ['USA','Canada','Australia']):
        return 'Others'
    else:
        return value
df['country'] = df['country'].apply(rem_country)
df['country'].value_counts()
# Out:
# USA          315
# Others        31
# Canada        15
# Australia      8
# Name: country, dtype: int64

# %%
df.head()
# Out:
#    rating  jersey                   team position    salary country  \
# 1      97       2   Los Angeles Clippers        F  32742000     USA
# 3      96       7          Brooklyn Nets        F  37199000     USA
# 4      96      13        Houston Rockets        G  38199000     USA
# 5      95      30  Golden State Warriors        G  40231758     USA
# 6      94       3     Los Angeles Lakers      F-C  27093019     USA
#
#    draft_year draft_round draft_peak  version
# 1        2011           1         15  NBA2k20
# 3        2007           1          2  NBA2k20
# 4        2009           1          3  NBA2k20
# 5        2009           1          7  NBA2k20
# 6        2012           1          1  NBA2k20

# %%
df['draft_round'].unique
# Out:
# <bound method Series.unique of 1      1
# 3      1
# 4      1
# 5      1
# 6      1
#       ..
# 457    1
# 458    1
# 459    1
# 460    1
# 462    1
# Name: draft_round, Length: 369, dtype: object>

# %%
df['draft_peak'].unique
# Out:
# <bound method Series.unique of 1      15
# 3       2
# 4       3
# 5       7
# 6       1
#        ..
# 457    27
# 458    13
# 459     4
# 460     3
# 462    24
# Name: draft_peak, Length: 369, dtype: object>

# %%
def removeundrafted(value):
    if value=='Undrafted':
        return 
    else:
        return value
    
df['draft_round'] = df['draft_round'].apply(removeundrafted)
df['draft_peak'] = df['draft_peak'].apply(removeundrafted)

df = df.dropna()

# %%
df.head()
# Out:
#    rating  jersey                   team position    salary country  \
# 1      97       2   Los Angeles Clippers        F  32742000     USA
# 3      96       7          Brooklyn Nets        F  37199000     USA
# 4      96      13        Houston Rockets        G  38199000     USA
# 5      95      30  Golden State Warriors        G  40231758     USA
# 6      94       3     Los Angeles Lakers      F-C  27093019     USA
#
#    draft_year draft_round draft_peak  version
# 1        2011           1         15  NBA2k20
# 3        2007           1          2  NBA2k20
# 4        2009           1          3  NBA2k20
# 5        2009           1          7  NBA2k20
# 6        2012           1          1  NBA2k20

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['position'] = le.fit_transform(df['position'])
df['country'] = le.fit_transform(df['country'])
df['team'] = le.fit_transform(df['team'])
df['version'] = le.fit_transform(df['version'])

df.head()
# Out:
#    rating  jersey  team  position    salary  country  draft_year draft_round  \
# 1      97       2    12         2  32742000        3        2011           1
# 3      96       7     2         2  37199000        3        2007           1
# 4      96      13    10         5  38199000        3        2009           1
# 5      95      30     9         5  40231758        3        2009           1
# 6      94       3    13         3  27093019        3        2012           1
#
#   draft_peak  version
# 1         15        0
# 3          2        0
# 4          3        0
# 5          7        0
# 6          1        0

# %%
x = df.drop(['salary'], axis = 1)
y = df['salary']
df.head()
# Out:
#    rating  jersey  team  position    salary  country  draft_year draft_round  \
# 1      97       2    12         2  32742000        3        2011           1
# 3      96       7     2         2  37199000        3        2007           1
# 4      96      13    10         5  38199000        3        2009           1
# 5      95      30     9         5  40231758        3        2009           1
# 6      94       3    13         3  27093019        3        2012           1
#
#   draft_peak  version
# 1         15        0
# 3          2        0
# 4          3        0
# 5          7        0
# 6          1        0

# %%
# def addn(value):
#     val=0
#     if value=='NBA2k20':
#         val=1
#     elif val=='NBA2k21':
#         value=2
#     else:
#         val=3
#     return val
# df['version']=df['version'].apply(addn)
# df['version']=df['version'].astype(np.float64)
# df.drop(['version'],axis=1,inplace=True)
df.head()
# Out:
#    rating  jersey  team  position    salary  country  draft_year draft_round  \
# 1      97       2    12         2  32742000        3        2011           1
# 3      96       7     2         2  37199000        3        2007           1
# 4      96      13    10         5  38199000        3        2009           1
# 5      95      30     9         5  40231758        3        2009           1
# 6      94       3    13         3  27093019        3        2012           1
#
#   draft_peak  version
# 1         15        0
# 3          2        0
# 4          3        0
# 5          7        0
# 6          1        0

# %%
df['draft_round']=df['draft_round'].astype(np.int64)

# %%
df['draft_peak']=df['draft_peak'].astype(np.int64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 317 entries, 1 to 462
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   rating       317 non-null    int64
#  1   jersey       317 non-null    int64
#  2   team         317 non-null    int32
#  3   position     317 non-null    int32
#  4   salary       317 non-null    int64
#  5   country      317 non-null    int32
#  6   draft_year   317 non-null    int64
#  7   draft_round  317 non-null    int64
#  8   draft_peak   317 non-null    int64
#  9   version      317 non-null    int32
# dtypes: int32(4), int64(6)
# memory usage: 22.3 KB

# %%
df.drop(labels=['salary'],axis=1,inplace=True);

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train, y_train)
predictions=lr.predict(x_test)
predictions
# Out:
# array([ 8929257.18836474,  2438096.44288182,  4340868.922822  ,
#         5375040.12446094,   267777.10055041, 15374938.10686231,
#        15877795.29818058, 11847027.20184159,  5686772.97798514,
#         4866655.1595912 , 12762916.04383516,  -111242.67290306,
#        16299217.65277338,  1225986.50427032,  9134791.27064252,
#        14047670.64900231, 15541646.9443233 , 19754520.14183116,
#        22535474.83944225, 16780453.1116209 , 39428257.32889199,
#        12110048.32986236, 16538720.38219237,  -253579.13750625,
#         7597455.64969373, 19148216.30135417,   507983.40575528,
#        10019698.723315  ,  9037735.80241513, 11287903.5941577 ,
#        35787129.54873419,  9546628.56565094, 23500018.36531401,
#        -1170346.82479072, 10205059.96749163,   371998.50320721,
#         8439354.44610262, 32615582.25359631,  5881367.37220359,
#         1732416.98124957,  1398341.10862255,  -709529.95194125,
#         2646812.38678861,  -142520.20866704, 12847564.89112043,
# ...

# %%
diff=y_test-predictions
diff
# Out:
# 124   -6.303540e+06
# 307    3.261036e+05
# 240   -2.470305e+06
# 183    1.684440e+06
# 373    3.299943e+06
#            ...
# 128    1.400100e+06
# 35    -2.528809e+06
# 17     9.028850e+06
# 416    4.007237e+06
# 200   -9.266794e+05
# Name: salary, Length: 64, dtype: float64

# %%
import seaborn as sns
sns.distplot(diff)
# Out:
# C:\Users\pabak\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='salary', ylabel='Density'>

# %%
import pickle
pickle.dump(lr,open('abc.sav','wb'))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 317 entries, 1 to 462
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   rating       317 non-null    int64
#  1   jersey       317 non-null    int64
#  2   team         317 non-null    int32
#  3   position     317 non-null    int32
#  4   country      317 non-null    int32
#  5   draft_year   317 non-null    int64
#  6   draft_round  317 non-null    int64
#  7   draft_peak   317 non-null    int64
#  8   version      317 non-null    int32
# dtypes: int32(4), int64(5)
# memory usage: 19.8 KB
